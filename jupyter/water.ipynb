# %%
import torch
print (torch.__version__)
# Out:
# 2.6.0+cpu

# %%
import csv
import pandas as pd
data = pd.read_csv('./water_potability.csv')

# %%
data['Hardness']
# Out:
# 0       204.890455
# 1       129.422921
# 2       224.236259
# 3       214.373394
# 4       181.101509
#            ...
# 3271    193.681735
# 3272    193.553212
# 3273    175.762646
# 3274    230.603758
# 3275    195.102299
# Name: Hardness, Length: 3276, dtype: float64

# %%
data.iloc[40]
# Out:
# ph                          NaN
# Hardness             233.858996
# Solids             11703.923907
# Chloramines            4.599388
# Sulfate              309.039320
# Conductivity         349.399633
# Organic_carbon        18.338893
# Trihalomethanes       42.677465
# Turbidity              3.510004
# Potability             0.000000
# Name: 40, dtype: float64

# %%
data.iloc[1:40]
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# 13        NaN  150.174923  27331.361962     6.838223  299.415781
# ...

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
data.mean()
# Out:
# ph                     7.080795
# Hardness             196.369496
# Solids             22014.092526
# Chloramines            7.122277
# Sulfate              333.775777
# Conductivity         426.205111
# Organic_carbon        14.284970
# Trihalomethanes       66.396293
# Turbidity              3.966786
# Potability             0.390110
# dtype: float64

# %%
data.fillna(data.mean(),inplace=True)
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

potability = data['Potability']
features = data.drop('Potability',axis=1)
target = data['Potability']

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
print(features)
scaled_features
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
from sklearn.model_selection import train_test_split
training_a,testing_a,training_b,testing_b = train_test_split(scaled_features,target,test_size=.2)

#print(testing_a.size)
#training_b.size
print(scaled_features.size)
# Out:
# 29484

# %%
from sklearn.model_selection import train_test_split
training_features,evalution_features,training_targets,evaluation_targets = train_test_split(scaled_features,target,test_size=.2,random_state=42)
print(scaled_features.size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 training_features,evalution_features,training_targets,evaluation_targets = train_test_split(scaled_features,target,test_size=.2,random_state=42)
#       3 print(scaled_features.size)
#
# File ~/default/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
tf_tensor = torch.tensor(training_features,dtype=torch.float32)
tf_somethin_else = torch.tensor(evalution_features,dtype=torch.float32)
tf_tensor
tf_somethin_else
# Out:
# tensor([[-6.0431e-16, -3.9083e-01, -1.7712e-01,  ...,  1.7819e+00,
#           3.9550e-02,  1.1789e+00],
#         [-2.9777e-01, -2.2680e-01,  1.2387e+00,  ...,  1.2753e-01,
#           9.1870e-02,  7.6309e-01],
#         [ 5.2068e-01,  8.4227e-01,  1.4258e-01,  ..., -2.6552e-01,
#          -1.4791e+00, -1.8953e+00],
#         ...,
#         [ 2.5743e-01,  6.4885e-01, -2.9400e-01,  ...,  5.3006e-02,
#          -5.8349e-01, -1.6114e-01],
#         [-8.2883e-01, -3.4386e-01,  2.5156e+00,  ...,  3.0871e-01,
#          -4.3066e-01,  1.9745e+00],
#         [-6.0431e-16,  7.3561e-01,  6.9817e-01,  ...,  9.8176e-01,
#           1.2971e+00, -5.0908e-01]])

# %%
from torch import nn as nn
#fake tensor data
input_tensor = torch.tensor([
    [1.0,1.0,1.0],
    ])
    #Building layers
    # 1. Start with value between input and output sizes (3 and 1)
    # 2. Use powers of 2
    # 3. 
    # 4. Don't use too many layers
#input linear layer
layer_input = nn.Linear(3,2)
hidden_layer1 = nn.Linear(2,1)

output_of_all = layer_input(input_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from torch import nn as nn
#       2 #fake tensor data
# ----> 3 input_tensor = torch.tensor([
#       4     [1.0,1.0,1.0],
#       5     ])
#       6     #Building layers
#       7     # 1. Start with value between input and output sizes (3 and 1)
#       8     # 2. Use powers of 2
#       9     # 3.
#      10     # 4. Don't use too many layers
#      11 #input linear layer
#      12 layer_input = nn.Linear(3,2)
#
# NameError: name 'torch' is not defined
